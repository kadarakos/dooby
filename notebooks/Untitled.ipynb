# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import datasets
import sys
import scipy
sys.path.append("../")
plot_kwds = {'alpha' : 0.5, 's' : 80, 'linewidths':0}

# %%
from dbscan import find_clusters
from util import make_dbscan_data

# %%
X = make_dbscan_data()
plt.scatter(X.T[0], X.T[1], color='b', **plot_kwds)

# %%
clustering = find_clusters(X)
plt.scatter(clustering.X.T[0], clustering.X.T[1], c=clustering.assignment, **plot_kwds)
